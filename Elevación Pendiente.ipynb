# %%
##Autor: Ian Meza
#Fecha 18/08/2021
#Descripción: Secuencia para crear un archivo de estilos para GeoServer en formato .sld 
#Indice NDSI

#Importación de librerías
import pandas as pd

#Funciones
def leerreferencia():
    a=[]
    with open('sld.txt', 'r') as f:
        a = f.read()
    f.closed
    return a
    
def generarrangos(minimo,maximo):
    diferencia = maximo - minimo
    div = diferencia/5
    
    r1i = minimo
    r1s = div+minimo
    
    r2i = r1s
    r2s = div+r2i
    
    r3i = r2s
    r3s = div+r3i
    
    r4i = r3s
    r4s = div+r4i
    
    r5i = r4s
    r5s = maximo
    
    r1 = str(r1i)+" - "+str(r1s)
    r2 = str(r2i)+" - "+str(r2s)
    r3 = str(r3i)+" - "+str(r3s)
    r4 = str(r4i)+" - "+str(r4s)
    r5 = str(r5i)+" - "+str(r5s)
    
    rangos = [r1,r2,r3,r4,r5]
    minimos = [r1i,r2i,r3i,r4i,r5i]
    maximos = [r1s,r2s,r3s,r4s,r5s]
    
    return rangos, minimos, maximos

def leerpaletas(paleta):
    paletas = pd.read_excel("Paletas SLD con Variables Censo.xlsx", sheet_name="Índices")
    paso = paletas["No"] == paleta
    paleta = paletas[paso]
    pal = paleta["Código"]
    return list(pal)

def sustitucion(minimo,maximo,variable, codpaleta):
    a = leerreferencia()
    inicio = a.split("<se:Rule>")[0]
    inicio = inicio.replace("Datos_Censo_2017_Comuna", "stats_indice_ndsi_comuna")
    final = a.split("<se:Rule>")[1].split("</se:Rule>")[1]
    referencia = "\n        <se:Rule>"+a.split("<se:Rule>")[1].split("</se:Rule>")[0]+"</se:Rule>"
    referencia = "        <se:Rule>"+a.split("<se:Rule>")[1].replace("COLECTIVAS", variable)
    try:
        codpaleta = diccionario[variable]
    except:
        pass
        
    rangos,minimos,maximos = generarrangos(minimo,maximo)
    
    paleta = leerpaletas(codpaleta)
    
    salida = []
    for i in range(5):
        
        ref = referencia.replace("<se:Name>4 - 55.4</se:Name>", "<se:Name>"+rangos[i]+"</se:Name>")
        ref = ref.replace("<se:Title>4 - 55.4</se:Title>", "<se:Title>"+rangos[i]+"</se:Title>")
        ref = ref.replace("<ogc:Literal>4</ogc:Literal>", "<ogc:Literal>"+str(minimos[i])+"</ogc:Literal>")
        ref = ref.replace("<ogc:Literal>55.4</ogc:Literal>", "<ogc:Literal>"+str(maximos[i])+"</ogc:Literal>")
        ref = ref.replace("fff5eb", str(paleta[i]))
        ref = ref.replace("</se:FeatureTypeStyle>", "")
        ref = ref.replace("</UserStyle>", "")
        ref = ref.replace("</NamedLayer>", "")
        ref = ref.replace("</StyledLayerDescriptor>", "")
        salida.append(ref)
    
    cuerpo = ""
    for i in salida:
        cuerpo = cuerpo+i
    salida2 = inicio+cuerpo+final
    return salida2

def guardararchivo(territorio, variable, minimo , maximo, codpaleta):

#   | p = provincia | r = región | c = comuna | m = manzana |
    text_file = open(f"indice_ndsi_c{territorio}_{variable}.sld", "w")

    text_file.write(sustitucion(minimo,maximo,variable, codpaleta))

    text_file.close()

# %%
#Proceso final Precipitaciones
df = pd.read_excel("https://github.com/Sud-Austral/SLD/blob/main/stats_indice_ndsi_comuna.xlsx?raw=true")
diccionario=22

#VARIABLES POSIBLES: PROVINCIA , REGION

for i in df["COMUNA"].unique():
    df_aux = df[df["COMUNA"] == i ]
    
    for j in df.columns[7:]:
        minimo = df_aux[j].min()
        maximo = df_aux[j].max()
        #codpaleta = pal
        #print(diccionario[j])
        guardararchivo(i,j,minimo,maximo,diccionario)

# %%
##Autor: Ian Meza
#Fecha 18/08/2021
#Descripción: Secuencia para crear un archivo de estilos para GeoServer en formato .sld 


#Importación de librerías
import pandas as pd

#Funciones
def leerreferencia():
    a=[]
    with open('sld.txt', 'r') as f:
        a = f.read()
    f.closed
    return a
    
def generarrangos(minimo,maximo):
    diferencia = maximo - minimo
    div = diferencia/5
    
    r1i = minimo
    r1s = div+minimo
    
    r2i = r1s
    r2s = div+r2i
    
    r3i = r2s
    r3s = div+r3i
    
    r4i = r3s
    r4s = div+r4i
    
    r5i = r4s
    r5s = maximo
    
    r1 = str(r1i)+" - "+str(r1s)
    r2 = str(r2i)+" - "+str(r2s)
    r3 = str(r3i)+" - "+str(r3s)
    r4 = str(r4i)+" - "+str(r4s)
    r5 = str(r5i)+" - "+str(r5s)
    
    rangos = [r1,r2,r3,r4,r5]
    minimos = [r1i,r2i,r3i,r4i,r5i]
    maximos = [r1s,r2s,r3s,r4s,r5s]
    
    return rangos, minimos, maximos

def leerpaletas(paleta):
    paletas = pd.read_excel("Paletas SLD con Variables Censo.xlsx", sheet_name="fisicas ")
    paso = paletas["No"] == paleta
    paleta = paletas[paso]
    pal = paleta["Código"]
    return list(pal)

def sustitucion(minimo,maximo,variable, codpaleta):
    a = leerreferencia()
    inicio = a.split("<se:Rule>")[0]
    inicio = inicio.replace("Datos_Censo_2017_Comuna", "stats_consolidado_elevacion_pendiente_por_columna_comuna")
    final = a.split("<se:Rule>")[1].split("</se:Rule>")[1]
    referencia = "\n        <se:Rule>"+a.split("<se:Rule>")[1].split("</se:Rule>")[0]+"</se:Rule>"
    referencia = "        <se:Rule>"+a.split("<se:Rule>")[1].replace("COLECTIVAS", variable)
    try:
        codpaleta = diccionario[variable]
    except:
        pass
        
    rangos,minimos,maximos = generarrangos(minimo,maximo)
    
    paleta = leerpaletas(codpaleta)
    
    salida = []
    for i in range(5):
        
        ref = referencia.replace("<se:Name>4 - 55.4</se:Name>", "<se:Name>"+rangos[i]+"</se:Name>")
        ref = ref.replace("<se:Title>4 - 55.4</se:Title>", "<se:Title>"+rangos[i]+"</se:Title>")
        ref = ref.replace("<ogc:Literal>4</ogc:Literal>", "<ogc:Literal>"+str(minimos[i])+"</ogc:Literal>")
        ref = ref.replace("<ogc:Literal>55.4</ogc:Literal>", "<ogc:Literal>"+str(maximos[i])+"</ogc:Literal>")
        ref = ref.replace("fff5eb", str(paleta[i]))
        ref = ref.replace("</se:FeatureTypeStyle>", "")
        ref = ref.replace("</UserStyle>", "")
        ref = ref.replace("</NamedLayer>", "")
        ref = ref.replace("</StyledLayerDescriptor>", "")
        salida.append(ref)
    
    cuerpo = ""
    for i in salida:
        cuerpo = cuerpo+i
    salida2 = inicio+cuerpo+final
    return salida2

def guardararchivo(territorio, variable, minimo , maximo, codpaleta):

#   | p = provincia | r = región | c = comuna | m = manzana |
    text_file = open(f"elevacion_pendiente_columna_c{territorio}_{variable}.sld", "w")

    text_file.write(sustitucion(minimo,maximo,variable, codpaleta))

    text_file.close()

# %%
#Proceso final Precipitaciones
df = pd.read_excel("https://github.com/Sud-Austral/SLD/blob/main/stats_consolidado_elevacion_pendiente_por_columna_comuna.xlsx?raw=true")
diccionario=2

#VARIABLES POSIBLES: PROVINCIA , REGION

for i in df["COMUNA"].unique():
    df_aux = df[df["COMUNA"] == i ]
    
    for j in df.columns[7:]:
        minimo = df_aux[j].min()
        maximo = df_aux[j].max()
        #codpaleta = pal
        #print(diccionario[j])
        guardararchivo(i,j,minimo,maximo,diccionario)

# %%
##Autor: Ian Meza
#Fecha 18/08/2021
#Descripción: Secuencia para crear un archivo de estilos para GeoServer en formato .sld 


#Importación de librerías
import pandas as pd

#Funciones
def leerreferencia():
    a=[]
    with open('sld.txt', 'r') as f:
        a = f.read()
    f.closed
    return a
    
def generarrangos(minimo,maximo):
    diferencia = maximo - minimo
    div = diferencia/5
    
    r1i = minimo
    r1s = div+minimo
    
    r2i = r1s
    r2s = div+r2i
    
    r3i = r2s
    r3s = div+r3i
    
    r4i = r3s
    r4s = div+r4i
    
    r5i = r4s
    r5s = maximo
    
    r1 = str(r1i)+" - "+str(r1s)
    r2 = str(r2i)+" - "+str(r2s)
    r3 = str(r3i)+" - "+str(r3s)
    r4 = str(r4i)+" - "+str(r4s)
    r5 = str(r5i)+" - "+str(r5s)
    
    rangos = [r1,r2,r3,r4,r5]
    minimos = [r1i,r2i,r3i,r4i,r5i]
    maximos = [r1s,r2s,r3s,r4s,r5s]
    
    return rangos, minimos, maximos

def leerpaletas(paleta):
    paletas = pd.read_excel("Paletas SLD con Variables Censo.xlsx", sheet_name="fisicas ")
    paso = paletas["No"] == paleta
    paleta = paletas[paso]
    pal = paleta["Código"]
    return list(pal)

def sustitucion(minimo,maximo,variable, codpaleta):
    a = leerreferencia()
    inicio = a.split("<se:Rule>")[0]
    inicio = inicio.replace("Datos_Censo_2017_Comuna", "stats_consolidado_suelos_por_banda_comuna")
    final = a.split("<se:Rule>")[1].split("</se:Rule>")[1]
    referencia = "\n        <se:Rule>"+a.split("<se:Rule>")[1].split("</se:Rule>")[0]+"</se:Rule>"
    referencia = "        <se:Rule>"+a.split("<se:Rule>")[1].replace("COLECTIVAS", variable)
    try:
        codpaleta = diccionario[variable]
    except:
        pass
        
    rangos,minimos,maximos = generarrangos(minimo,maximo)
    
    paleta = leerpaletas(codpaleta)
    
    salida = []
    for i in range(5):
        
        ref = referencia.replace("<se:Name>4 - 55.4</se:Name>", "<se:Name>"+rangos[i]+"</se:Name>")
        ref = ref.replace("<se:Title>4 - 55.4</se:Title>", "<se:Title>"+rangos[i]+"</se:Title>")
        ref = ref.replace("<ogc:Literal>4</ogc:Literal>", "<ogc:Literal>"+str(minimos[i])+"</ogc:Literal>")
        ref = ref.replace("<ogc:Literal>55.4</ogc:Literal>", "<ogc:Literal>"+str(maximos[i])+"</ogc:Literal>")
        ref = ref.replace("fff5eb", str(paleta[i]))
        ref = ref.replace("</se:FeatureTypeStyle>", "")
        ref = ref.replace("</UserStyle>", "")
        ref = ref.replace("</NamedLayer>", "")
        ref = ref.replace("</StyledLayerDescriptor>", "")
        salida.append(ref)
    
    cuerpo = ""
    for i in salida:
        cuerpo = cuerpo+i
    salida2 = inicio+cuerpo+final
    return salida2

def guardararchivo(territorio, variable, minimo , maximo, codpaleta):

#   | p = provincia | r = región | c = comuna | m = manzana |
    text_file = open(f"suelos_por_banda_c{territorio}_{variable}.sld", "w")

    text_file.write(sustitucion(minimo,maximo,variable, codpaleta))

    text_file.close()

# %%
diccionario = {}
diccionario = {"v020":4,
                "v021":3,
                "v022":3,
                "v023":3,
                "v024":3,
                "v025":3,
                "v026":13,
                "v027":13,
                "v028":13,
                "v029":13,
                "v030":13,
                "v031":13,
                "v032":4,
                "v033":4,
                "v034":4,
                "v035":4,
                "v036":4,
                "v037":4,
                "v038":5,
                "v039":5,
                "v040":5,
                "v041":5,
                "v042":5,
                "v043":5,
                "v044":8,
                "v045":8,
                "v046":8,
                "v047":8,
                "v048":8,
                "v049":8,
                "v050":9,
                "v051":9,
                "v052":9,
                "v053":9,
                "v054":9,
                "v055":9,
                "v056":10,
                "v057":11,
                "v058":11,
                "v059":11,
                "v060":11,
                "v061":11,
                "v062":11,
                "v063":6,
                "v064":6,
                "v065":6,
                "v066":6,
                "v067":6,
                "v068":6,
                "v069":7,
                "v070":7,
                "v071":7,
                "v072":7,
                "v073":7,
                "v074":7,
                "v075":12,
                "v076":12,
                "v077":12,
                "v078":12,
                "v079":12,
                "v080":12,
                "v081":3,
                "v082":3,
                "v083":3,
                "v084":3,
                "v085":3,
                "v086":3,
                "v087":3,
                "v088":3,
                "v089":3,
                "v090":3,
                "v091":3,
                "v092":3,
                "v093":5,
                "v094":5,
                "v095":5,
                "v096":5,
                "v097":5,
                "v098":5,
                "v099":5,
                "v100":5,
                "v101":5,
                "v102":5,
                "v103":5,
                "v104":5,
                "v105":8,
                "v106":8,
                "v107":8,
                "v108":8,
                "v109":8,
                "v110":8,
                "v111":8,
                "v112":8,
                "v113":8,
                "v114":8,
                "v115":8,
                "v116":8,
                "v117":9,
                "v118":9,
                "v119":9,
                "v120":9,
                "v121":9,
                "v122":9,
                "v123":9,
                "v124":9,
                "v125":9,
                "v126":9,
                "v127":9,
                "v128":9,
                "v129":11,
                "v130":11,
                "v131":11,
                "v132":11,
                "v133":11,
                "v134":11,
                "v135":6,
                "v136":6,
                "v137":6,
                "v138":6,
                "v139":6,
                "v140":6,
                "v141":6,
                "v142":6,
                "v143":6,
                "v144":6,
                "v145":6,
                "v146":6,
                "v147":7,
                "v148":7,
                "v149":7,
                "v150":7,
                "v151":7,
                "v152":7,
                "v153":7,
                "v154":7,
                "v155":7,
                "v156":7,
                "v157":7,
                "v158":7,
                "v159":12,
                "v160":12,
                "v161":12,
                "v162":12,
                "v163":12,
                "v164":12,
                "v165":12,
                "v166":12,
                "v167":12,
                "v168":12,
                "v169":12,
                "v170":12,
}

# %%
df = pd.read_excel("https://github.com/Sud-Austral/SLD/blob/main/stats_consolidado_suelos_por_banda_comuna.xlsx?raw=true")
df.columns[7:]
df = df.rename(columns={"bdod_0-5cm_mean":"v020",
                        "bdod_100-200cm_mean":"v021",
                        "bdod_15-30cm_mean":"v022",
                        "bdod_30-60cm_mean":"v023",
                        "bdod_5-15cm_mean":"v024",
                        "bdod_60-100cm_mean":"v025",
                        "cec_0-5cm mmol(c)/kg":"v026",
                        "cec_100-200cm mmol(c)/kg":"v027",
                        "cec_15-30cm mmol(c)/kg":"v028",
                        "cec_30-60cm mmol(c)/kg":"v029",
                        "cec_5-15cm mmol(c)/kg":"v030",
                        "cec_60-100cm mmol(c)/kg":"v031",
                        "cfvo_0-5cm cm3/dm3":"v032",
                        "cfvo_100-200cm cm3/dm3":"v033",
                        "cfvo_15-30cm cm3/dm3":"v034",
                        "cfvo_30-60cm cm3/dm3":"v035",
                        "cfvo_5-15cm cm3/dm3":"v036",
                        "cfvo_60-100cm cm3/dm3":"v037",
                        "clay_0-5cm_mean":"v038",
                        "clay_100-200cm_mean":"v039",
                        "clay_15-30cm_mean":"v040",
                        "clay_30-60cm_mean":"v041",
                        "clay_5-15cm_mean":"v042",
                        "clay_60-100cm_mean":"v043",
                        "nitrogen_0-5cm_mean":"v044",
                        "nitrogen_100-200cm_mean":"v045",
                        "nitrogen_15-30cm_mean":"v046",
                        "nitrogen_30-60cm_mean":"v047",
                        "nitrogen_5-15cm_mean":"v048",
                        "nitrogen_60-100cm_mean":"v049",
                        "ocd_0-5cm_mean":"v050",
                        "ocd_100-200cm_mean":"v051",
                        "ocd_15-30cm_mean":"v052",
                        "ocd_30-60cm_mean":"v053",
                        "ocd_5-15cm_mean":"v054",
                        "ocd_60-100cm_mean":"v055",
                        "ocs_0-30cm t/ha":"v056",
                        "phh2o_0-5cm pH * 10":"v057",
                        "phh2o_100-200cm pH * 10":"v058",
                        "phh2o_15-30cm pH * 10":"v059",
                        "phh2o_30-60cm pH * 10":"v060",
                        "phh2o_5-15cm pH * 10":"v061",
                        "phh2o_60-100cm pH * 10":"v062",
                        "sand_0-5cm_mean":"v063",
                        "sand_100-200cm_mean":"v064",
                        "sand_15-30cm_mean":"v065",
                        "sand_30-60cm_mean":"v066",
                        "sand_5-15cm_mean":"v067",
                        "sand_60-100cm_mean":"v068",
                        "silt_0-5cm_mean":"v069",
                        "silt_100-200cm_mean":"v070",
                        "silt_15-30cm_mean":"v071",
                        "silt_30-60cm_mean":"v072",
                        "silt_5-15cm_mean":"v073",
                        "silt_60-100cm_mean":"v074",
                        "soc_0-5cm_mean":"v075",
                        "soc_100-200cm_mean":"v076",
                        "soc_15-30cm_mean":"v077",
                        "soc_30-60cm_mean":"v078",
                        "soc_5-15cm_mean":"v079",
                        "soc_60-100cm_mean":"v080",
                        "bdod_0-5cm_mean g/cm3":"v081",
                        "bdod_0-5cm_mean kg/m3":"v082",
                        "bdod_100-200cm_mean g/cm3":"v083",
                        "bdod_100-200cm_mean kg/m3":"v084",
                        "bdod_15-30cm_mean g/cm3":"v085",
                        "bdod_15-30cm_mean kg/m3":"v086",
                        "bdod_30-60cm_mean g/cm3":"v087",
                        "bdod_30-60cm_mean kg/m3":"v088",
                        "bdod_5-15cm_mean g/cm3":"v089",
                        "bdod_5-15cm_mean kg/m3":"v090",
                        "bdod_60-100cm_mean g/cm3":"v091",
                        "bdod_60-100cm_mean kg/m3":"v092",
                        "clay_0-5cm_mean g/cm3":"v093",
                        "clay_0-5cm_mean kg/m3":"v094",
                        "clay_100-200cm_mean g/cm3":"v095",
                        "clay_100-200cm_mean kg/m3":"v096",
                        "clay_15-30cm_mean g/cm3":"v097",
                        "clay_15-30cm_mean kg/m3":"v098",
                        "clay_30-60cm_mean g/cm3":"v099",
                        "clay_30-60cm_mean kg/m3":"v100",
                        "clay_5-15cm_mean g/cm3":"v101",
                        "clay_5-15cm_mean kg/m3":"v102",
                        "clay_60-100cm_mean g/cm3":"v103",
                        "clay_60-100cm_mean kg/m3":"v104",
                        "nitrogen_0-5cm_mean g/cm3":"v105",
                        "nitrogen_0-5cm_mean kg/m3":"v106",
                        "nitrogen_100-200cm_mean g/cm3":"v107",
                        "nitrogen_100-200cm_mean kg/m3":"v108",
                        "nitrogen_15-30cm_mean g/cm3":"v109",
                        "nitrogen_15-30cm_mean kg/m3":"v110",
                        "nitrogen_30-60cm_mean g/cm3":"v111",
                        "nitrogen_30-60cm_mean kg/m3":"v112",
                        "nitrogen_5-15cm_mean g/cm3":"v113",
                        "nitrogen_5-15cm_mean kg/m3":"v114",
                        "nitrogen_60-100cm_mean g/cm3":"v115",
                        "nitrogen_60-100cm_mean kg/m3":"v116",
                        "ocd_0-5cm_mean g/cm3":"v117",
                        "ocd_0-5cm_mean kg/m3":"v118",
                        "ocd_100-200cm_mean g/cm3":"v119",
                        "ocd_100-200cm_mean kg/m3":"v120",
                        "ocd_15-30cm_mean g/cm3":"v121",
                        "ocd_15-30cm_mean kg/m3":"v122",
                        "ocd_30-60cm_mean g/cm3":"v123",
                        "ocd_30-60cm_mean kg/m3":"v124",
                        "ocd_5-15cm_mean g/cm3":"v125",
                        "ocd_5-15cm_mean kg/m3":"v126",
                        "ocd_60-100cm_mean g/cm3":"v127",
                        "ocd_60-100cm_mean kg/m3":"v128",
                        "phh2o_0-5cm pH":"v129",
                        "phh2o_100-200cm pH":"v130",
                        "phh2o_15-30cm pH":"v131",
                        "phh2o_30-60cm pH":"v132",
                        "phh2o_5-15cm pH":"v133",
                        "phh2o_60-100cm pH":"v134",
                        "sand_0-5cm_mean g/cm3":"v135",
                        "sand_0-5cm_mean kg/m3":"v136",
                        "sand_100-200cm_mean g/cm3":"v137",
                        "sand_100-200cm_mean kg/m3":"v138",
                        "sand_15-30cm_mean g/cm3":"v139",
                        "sand_15-30cm_mean kg/m3":"v140",
                        "sand_30-60cm_mean g/cm3":"v141",
                        "sand_30-60cm_mean kg/m3":"v142",
                        "sand_5-15cm_mean g/cm3":"v143",
                        "sand_5-15cm_mean kg/m3":"v144",
                        "sand_60-100cm_mean g/cm3":"v145",
                        "sand_60-100cm_mean kg/m3":"v146",
                        "silt_0-5cm_mean g/cm3":"v147",
                        "silt_0-5cm_mean kg/m3":"v148",
                        "silt_100-200cm_mean g/cm3":"v149",
                        "silt_100-200cm_mean kg/m3":"v150",
                        "silt_15-30cm_mean g/cm3":"v151",
                        "silt_15-30cm_mean kg/m3":"v152",
                        "silt_30-60cm_mean g/cm3":"v153",
                        "silt_30-60cm_mean kg/m3":"v154",
                        "silt_5-15cm_mean g/cm3":"v155",
                        "silt_5-15cm_mean kg/m3":"v156",
                        "silt_60-100cm_mean g/cm3":"v157",
                        "silt_60-100cm_mean kg/m3":"v158",
                        "soc_0-5cm_mean g/cm3":"v159",
                        "soc_0-5cm_mean kg/m3":"v160",
                        "soc_100-200cm_mean g/cm3":"v161",
                        "soc_100-200cm_mean kg/m3":"v162",
                        "soc_15-30cm_mean g/cm3":"v163",
                        "soc_15-30cm_mean kg/m3":"v164",
                        "soc_30-60cm_mean g/cm3":"v165",
                        "soc_30-60cm_mean kg/m3":"v166",
                        "soc_5-15cm_mean g/cm3":"v167",
                        "soc_5-15cm_mean kg/m3":"v168",
                        "soc_60-100cm_mean g/cm3":"v169",
                        "soc_60-100cm_mean kg/m3":"v170"
                        })
df
# Out:
#       COMUNA    NOM_COMUNA  REGION              NOM_REGION  PROVINCIA  \
# 0      10101  PUERTO MONTT      10     REGIÓN DE LOS LAGOS        101
# 1      10101  PUERTO MONTT      10     REGIÓN DE LOS LAGOS        101
# 2      10101  PUERTO MONTT      10     REGIÓN DE LOS LAGOS        101
# 3      10101  PUERTO MONTT      10     REGIÓN DE LOS LAGOS        101
# 4      10101  PUERTO MONTT      10     REGIÓN DE LOS LAGOS        101
# ...      ...           ...     ...                     ...        ...
# 2304    9211      VICTORIA       9  REGIÓN DE LA ARAUCANÍA         92
# 2305    9211      VICTORIA       9  REGIÓN DE LA ARAUCANÍA         92
# 2306    9211      VICTORIA       9  REGIÓN DE LA ARAUCANÍA         92
# 2307    9211      VICTORIA       9  REGIÓN DE LA ARAUCANÍA         92
# 2308    9211      VICTORIA       9  REGIÓN DE LA ARAUCANÍA         92
#
#       NOM_PROVIN Descriptor        v020        v021        v022  ...  \
# 0     LLANQUIHUE       Min.   67.000000   85.000000   73.000000  ...
# 1     LLANQUIHUE    1st Qu.   73.000000   96.000000   81.000000  ...
# 2     LLANQUIHUE     Median   76.000000  102.000000   83.000000  ...
# 3     LLANQUIHUE       Mean   76.545922  102.461143   84.894669  ...
# 4     LLANQUIHUE    3rd Qu.   81.000000  110.000000   89.000000  ...
# ...          ...        ...         ...         ...         ...  ...
# 2304     MALLECO       Mean  105.167866  127.567546  113.537970  ...
# 2305     MALLECO    3rd Qu.  111.000000  132.000000  119.000000  ...
# 2306     MALLECO       Min.   86.000000  111.000000   94.000000  ...
# 2307     MALLECO    1st Qu.  100.000000  123.000000  108.000000  ...
# 2308     MALLECO     Median  105.000000  127.000000  113.000000  ...
#
#                v161      v162           v163      v164           v165  \
# 0     236000.000000  0.023600  102000.000000  0.068000  105300.000000
# 1     558000.000000  0.055800  139350.000000  0.092900  179100.000000
# 2     627000.000000  0.062700  152100.000000  0.101400  199200.000000
# 3     634229.929351  0.063423  154015.510597  0.102677  201608.285164
# 4     705000.000000  0.070500  166200.000000  0.110800  220500.000000
# ...             ...       ...            ...       ...            ...
# 2304  310832.933653  0.031083   76167.146283  0.050778  111126.378897
# 2305  340000.000000  0.034000   80250.000000  0.053500  119700.000000
# 2306  174000.000000  0.017400   57150.000000  0.038100   69900.000000
# 2307  265000.000000  0.026500   69750.000000  0.046500   99000.000000
# 2308  297000.000000  0.029700   74250.000000  0.049500  108600.000000
#
#           v166           v167      v168           v169      v170
# 0     0.035100  112100.000000  0.112100   96400.000000  0.024100
# 1     0.059700  138400.000000  0.138400  225600.000000  0.056400
# 2     0.066400  149900.000000  0.149900  253600.000000  0.063400
# 3     0.067203  150954.014130  0.150954  256282.594733  0.064071
# 4     0.073500  162900.000000  0.162900  284000.000000  0.071000
# ...        ...            ...       ...            ...       ...
# 2304  0.037042   85339.088729  0.085339  125890.967226  0.031473
# 2305  0.039900   90750.000000  0.090750  136800.000000  0.034200
# 2306  0.023300   59500.000000  0.059500   77600.000000  0.019400
# 2307  0.033000   79900.000000  0.079900  108000.000000  0.027000
# 2308  0.036200   85000.000000  0.085000  121200.000000  0.030300
#
# [2309 rows x 158 columns]

# %%
df = pd.read_excel("https://github.com/Sud-Austral/SLD/blob/main/stats_consolidado_suelos_por_banda_comuna.xlsx?raw=true")
cols = str(df.columns)
text_file = open(f"columnas_suelos_bandas.txt", "w")

text_file.write(cols)

text_file.close()

# %%
#Proceso final Precipitaciones
#df = pd.read_excel("https://github.com/Sud-Austral/SLD/blob/main/stats_consolidado_suelos_por_banda_comuna.xlsx?raw=true")
#diccionario=2

#VARIABLES POSIBLES: PROVINCIA , REGION

for i in df["COMUNA"].unique():
    df_aux = df[df["COMUNA"] == i ]
    
    for j in df.columns[7:]:
        minimo = df_aux[j].min()
        maximo = df_aux[j].max()
        #codpaleta = pal
        #print(diccionario[j])
        guardararchivo(i,j,minimo,maximo,diccionario)

# %%
##Autor: Ian Meza
#Fecha 18/08/2021
#Descripción: Secuencia para crear un archivo de estilos para GeoServer en formato .sld 


#Importación de librerías
import pandas as pd

#Funciones
def leerreferencia():
    a=[]
    with open('sld.txt', 'r') as f:
        a = f.read()
    f.closed
    return a
    
def generarrangos(minimo,maximo):
    diferencia = maximo - minimo
    div = diferencia/5
    
    r1i = minimo
    r1s = div+minimo
    
    r2i = r1s
    r2s = div+r2i
    
    r3i = r2s
    r3s = div+r3i
    
    r4i = r3s
    r4s = div+r4i
    
    r5i = r4s
    r5s = maximo
    
    r1 = str(r1i)+" - "+str(r1s)
    r2 = str(r2i)+" - "+str(r2s)
    r3 = str(r3i)+" - "+str(r3s)
    r4 = str(r4i)+" - "+str(r4s)
    r5 = str(r5i)+" - "+str(r5s)
    
    rangos = [r1,r2,r3,r4,r5]
    minimos = [r1i,r2i,r3i,r4i,r5i]
    maximos = [r1s,r2s,r3s,r4s,r5s]
    
    return rangos, minimos, maximos

def leerpaletas(paleta):
    paletas = pd.read_excel("Paletas SLD con Variables Censo.xlsx", sheet_name="Índices")
    paso = paletas["No"] == paleta
    paleta = paletas[paso]
    pal = paleta["Código"]
    return list(pal)

def sustitucion(minimo,maximo,variable, codpaleta):
    a = leerreferencia()
    inicio = a.split("<se:Rule>")[0]
    inicio = inicio.replace("Datos_Censo_2017_Comuna", "stats_indice_evi_comuna")
    final = a.split("<se:Rule>")[1].split("</se:Rule>")[1]
    referencia = "\n        <se:Rule>"+a.split("<se:Rule>")[1].split("</se:Rule>")[0]+"</se:Rule>"
    referencia = "        <se:Rule>"+a.split("<se:Rule>")[1].replace("COLECTIVAS", variable)
    try:
        codpaleta = diccionario[variable]
    except:
        pass
        
    rangos,minimos,maximos = generarrangos(minimo,maximo)
    
    paleta = leerpaletas(codpaleta)
    
    salida = []
    for i in range(5):
        
        ref = referencia.replace("<se:Name>4 - 55.4</se:Name>", "<se:Name>"+rangos[i]+"</se:Name>")
        ref = ref.replace("<se:Title>4 - 55.4</se:Title>", "<se:Title>"+rangos[i]+"</se:Title>")
        ref = ref.replace("<ogc:Literal>4</ogc:Literal>", "<ogc:Literal>"+str(minimos[i])+"</ogc:Literal>")
        ref = ref.replace("<ogc:Literal>55.4</ogc:Literal>", "<ogc:Literal>"+str(maximos[i])+"</ogc:Literal>")
        ref = ref.replace("fff5eb", str(paleta[i]))
        ref = ref.replace("</se:FeatureTypeStyle>", "")
        ref = ref.replace("</UserStyle>", "")
        ref = ref.replace("</NamedLayer>", "")
        ref = ref.replace("</StyledLayerDescriptor>", "")
        salida.append(ref)
    
    cuerpo = ""
    for i in salida:
        cuerpo = cuerpo+i
    salida2 = inicio+cuerpo+final
    return salida2

def guardararchivo(territorio, variable, minimo , maximo, codpaleta):

#   | p = provincia | r = región | c = comuna | m = manzana |
    text_file = open(f"indice_evi_c{territorio}_{variable}.sld", "w")

    text_file.write(sustitucion(minimo,maximo,variable, codpaleta))

    text_file.close()

# %%
#Proceso final Precipitaciones
df = pd.read_excel("https://github.com/Sud-Austral/SLD/blob/main/stats_indice_evi_comuna.xlsx?raw=true")
diccionario=19

#VARIABLES POSIBLES: PROVINCIA , REGION

for i in df["COMUNA"].unique():
    df_aux = df[df["COMUNA"] == i ]
    
    for j in df.columns[7:]:
        minimo = df_aux[j].min()
        maximo = df_aux[j].max()
        #codpaleta = pal
        #print(diccionario[j])
        guardararchivo(i,j,minimo,maximo,diccionario)
